# %% [markdown]
# <a href="https://colab.research.google.com/github/CassioRibeiro/PGM4/blob/main/PGM4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # ORGANIZANDO OS DADOS

# %% [markdown]
# ### Criando o frame com os dados de Abril

# %%
anp_abril = pd.read_csv('https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/arquivos/shpc/dsan/2023/precos-gasolina-etanol-04.csv', sep = ';')
anp_abril.head(3)
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             SE             SP   SOROCABA
# 1             SE             SP   SOROCABA
# 2             NE             AL  ARAPIRACA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2                      AUTO POSTO SAO FRANCISCO LTDA   12.706.529/0001-04
#
#               Nome da Rua Numero Rua Complemento          Bairro        Cep  \
# 0  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# 1  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# 2       RUA SAO FRANCISCO        274         NaN          CENTRO  57300-080
#
#     Produto Data da Coleta Valor de Venda  Valor de Compra Unidade de Medida  \
# 0    ETANOL     03/04/2023           3,37              NaN        R$ / litro
# 1  GASOLINA     03/04/2023           4,77              NaN        R$ / litro
# 2  GASOLINA     03/04/2023           5,68              NaN        R$ / litro
#
#         Bandeira
# 0         BRANCA
# 1         BRANCA
# 2  VIBRA ENERGIA

# %% [markdown]
# ### Adicionando a coluna de mês

# %%
anp_abril['Mes'] = 'ABRIL'
anp_abril.head(3)
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             SE             SP   SOROCABA
# 1             SE             SP   SOROCABA
# 2             NE             AL  ARAPIRACA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2                      AUTO POSTO SAO FRANCISCO LTDA   12.706.529/0001-04
#
#               Nome da Rua Numero Rua Complemento          Bairro        Cep  \
# 0  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# 1  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# 2       RUA SAO FRANCISCO        274         NaN          CENTRO  57300-080
#
#     Produto Data da Coleta Valor de Venda  Valor de Compra Unidade de Medida  \
# 0    ETANOL     03/04/2023           3,37              NaN        R$ / litro
# 1  GASOLINA     03/04/2023           4,77              NaN        R$ / litro
# 2  GASOLINA     03/04/2023           5,68              NaN        R$ / litro
#
#         Bandeira    Mes
# 0         BRANCA  ABRIL
# 1         BRANCA  ABRIL
# 2  VIBRA ENERGIA  ABRIL

# %% [markdown]
# ### Criando o frame com os dados de Março

# %%
anp_marco = pd.read_csv('https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/arquivos/shpc/dsan/2023/precos-gasolina-etanol-03.csv', sep = ';')
anp_marco.head(3)
# Out:
#   Regiao - Sigla Estado - Sigla   Municipio                   Revenda  \
# 0              N             AC  RIO BRANCO  CODEPE COMBUSTIVEIS LTDA
# 1              N             AC  RIO BRANCO  CODEPE COMBUSTIVEIS LTDA
# 2              N             AC  RIO BRANCO  CODEPE COMBUSTIVEIS LTDA
#
#        CNPJ da Revenda                    Nome da Rua Numero Rua  \
# 0   08.220.930/0001-62  LOTEAMENTO PORTAL DA AMAZONIA        S/N
# 1   08.220.930/0001-62  LOTEAMENTO PORTAL DA AMAZONIA        S/N
# 2   08.220.930/0001-62  LOTEAMENTO PORTAL DA AMAZONIA        S/N
#
#                            Complemento    Bairro        Cep  \
# 0  QUADRA 101 LTS 01,02,03,04, 05 E 33  CALAFATE  69905-801
# 1  QUADRA 101 LTS 01,02,03,04, 05 E 33  CALAFATE  69905-801
# 2  QUADRA 101 LTS 01,02,03,04, 05 E 33  CALAFATE  69905-801
#
#               Produto Data da Coleta Valor de Venda  Valor de Compra  \
# 0              ETANOL     01/03/2023           4,29              NaN
# 1  GASOLINA ADITIVADA     01/03/2023           5,39              NaN
# 2            GASOLINA     01/03/2023           5,39              NaN
#
#   Unidade de Medida       Bandeira
# 0        R$ / litro  VIBRA ENERGIA
# 1        R$ / litro  VIBRA ENERGIA
# 2        R$ / litro  VIBRA ENERGIA

# %% [markdown]
# ### Adicionando a coluna de mes

# %%
anp_marco['Mes'] = 'MARÇO'
anp_marco.head(3)
# Out:
#   Regiao - Sigla Estado - Sigla   Municipio                   Revenda  \
# 0              N             AC  RIO BRANCO  CODEPE COMBUSTIVEIS LTDA
# 1              N             AC  RIO BRANCO  CODEPE COMBUSTIVEIS LTDA
# 2              N             AC  RIO BRANCO  CODEPE COMBUSTIVEIS LTDA
#
#        CNPJ da Revenda                    Nome da Rua Numero Rua  \
# 0   08.220.930/0001-62  LOTEAMENTO PORTAL DA AMAZONIA        S/N
# 1   08.220.930/0001-62  LOTEAMENTO PORTAL DA AMAZONIA        S/N
# 2   08.220.930/0001-62  LOTEAMENTO PORTAL DA AMAZONIA        S/N
#
#                            Complemento    Bairro        Cep  \
# 0  QUADRA 101 LTS 01,02,03,04, 05 E 33  CALAFATE  69905-801
# 1  QUADRA 101 LTS 01,02,03,04, 05 E 33  CALAFATE  69905-801
# 2  QUADRA 101 LTS 01,02,03,04, 05 E 33  CALAFATE  69905-801
#
#               Produto Data da Coleta Valor de Venda  Valor de Compra  \
# 0              ETANOL     01/03/2023           4,29              NaN
# 1  GASOLINA ADITIVADA     01/03/2023           5,39              NaN
# 2            GASOLINA     01/03/2023           5,39              NaN
#
#   Unidade de Medida       Bandeira    Mes
# 0        R$ / litro  VIBRA ENERGIA  MARÇO
# 1        R$ / litro  VIBRA ENERGIA  MARÇO
# 2        R$ / litro  VIBRA ENERGIA  MARÇO

# %% [markdown]
# ### Concatenando os dois frames

# %%
relatorio = pd.concat([anp_abril,anp_marco], ignore_index= True)
relatorio.head(3)
# Out:
#   Regiao - Sigla Estado - Sigla  Municipio  \
# 0             SE             SP   SOROCABA
# 1             SE             SP   SOROCABA
# 2             NE             AL  ARAPIRACA
#
#                                              Revenda      CNPJ da Revenda  \
# 0  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 1  COMPETRO COMERCIO E DISTRIBUICAO DE DERIVADOS ...   00.003.188/0001-21
# 2                      AUTO POSTO SAO FRANCISCO LTDA   12.706.529/0001-04
#
#               Nome da Rua Numero Rua Complemento          Bairro        Cep  \
# 0  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# 1  RUA HUMBERTO DE CAMPOS        306         NaN  JARDIM ZULMIRA  18061-000
# 2       RUA SAO FRANCISCO        274         NaN          CENTRO  57300-080
#
#     Produto Data da Coleta Valor de Venda  Valor de Compra Unidade de Medida  \
# 0    ETANOL     03/04/2023           3,37              NaN        R$ / litro
# 1  GASOLINA     03/04/2023           4,77              NaN        R$ / litro
# 2  GASOLINA     03/04/2023           5,68              NaN        R$ / litro
#
#         Bandeira    Mes
# 0         BRANCA  ABRIL
# 1         BRANCA  ABRIL
# 2  VIBRA ENERGIA  ABRIL

# %% [markdown]
# ### Substituindo a virgula por ponto e convertendo a coluna 'Valor de Venda' para float para então conseguir fazer as devidas análises com os números

# %%
relatorio['Valor de Venda']= relatorio['Valor de Venda'].str.replace(',', '.')
relatorio['Valor de Venda'] = relatorio['Valor de Venda'].astype(float)

# %% [markdown]
# ### Separando os tipos de combustíveis para análises futuras

# %%
gasolina = relatorio.query('Produto == "GASOLINA"')

# %%
etanol = relatorio.query('Produto == "ETANOL"')

# %%
gasolina_aditivada = relatorio.query('Produto == "GASOLINA ADITIVADA"')

# %% [markdown]
# ### Agrupando as datas por mês para fazer o gráfico de comportamento referente a cada mês e seu respectivo tipo de combustível

# %%
etanol_abril = etanol.query('Mes == "ABRIL"')

# %%
etanol_marco = etanol.query('Mes == "MARÇO"')

# %%
gasolina_abril = gasolina.query('Mes == "ABRIL"')

# %%
gasolina_marco = gasolina.query('Mes == "MARÇO"')

# %%
aditivada_abril = gasolina_aditivada.query('Mes == "ABRIL"')

# %%
aditivada_marco = gasolina_aditivada.query('Mes == "MARÇO"')

# %%
preco_etanol_abril = etanol_abril[['Data da Coleta', 'Valor de Venda']].groupby('Data da Coleta').mean().sort_values(by = 'Data da Coleta').round(2)
preco_etanol_abril.head(2)
# Out:
#                 Valor de Venda
# Data da Coleta
# 03/04/2023                4.05
# 04/04/2023                4.13

# %%
preco_etanol_mar = etanol_marco[['Data da Coleta', 'Valor de Venda']].groupby('Data da Coleta').mean().sort_values(by = 'Data da Coleta').round(2)
preco_etanol_mar.head(2)
# Out:
#                 Valor de Venda
# Data da Coleta
# 01/03/2023                4.12
# 02/03/2023                4.20

# %%
preco_gasolina_abril = gasolina_abril[['Data da Coleta', 'Valor de Venda']].groupby('Data da Coleta').mean().sort_values(by = 'Data da Coleta').round(2)

# %%
preco_gasolina_marco = gasolina_marco[['Data da Coleta', 'Valor de Venda']].groupby('Data da Coleta').mean().sort_values(by = 'Data da Coleta').round(2)

# %%
preco_aditivada_abril = aditivada_abril[['Data da Coleta', 'Valor de Venda']].groupby('Data da Coleta').mean().sort_values(by = 'Data da Coleta').round(2)

# %%
preco_aditivada_marco = aditivada_marco[['Data da Coleta', 'Valor de Venda']].groupby('Data da Coleta').mean().sort_values(by = 'Data da Coleta').round(2)

# %% [markdown]
# # **RESPONDENDO AS QUERYS**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * **Gráfico de venda no mês de março**

# %%
# Criando o gráfico de linhas
fig, ax = plt.subplots(figsize = (30,6))
ax.plot(preco_gasolina_marco.index , preco_gasolina_marco['Valor de Venda'], label='Gasolina', color = 'yellow', linewidth=2, marker='o')
ax.plot(preco_etanol_mar.index , preco_etanol_mar['Valor de Venda'], label='Etanol', color = 'green',linewidth=2,marker='o')
ax.plot(preco_aditivada_marco.index , preco_aditivada_marco['Valor de Venda'], label='Etanol', color = 'red',linewidth=2, marker='o')

# Adicionando legendas e título
ax.legend()
ax.set_xlabel('Data')
ax.set_ylabel('Preço médio de revenda')
ax.set_title('COMPORTAMENTO DE PREÇO - Março/2023')
#ax.set_facecolor('grey')
ax.grid(True)
# Mostrando o gráfico
plt.show()

# %% [markdown]
# * **Gráfico de venda no mês de Abril**

# %%
# Criando o gráfico de linhas
fig, ax = plt.subplots(figsize = (30,6))
ax.plot(preco_gasolina_abril.index , preco_gasolina_abril['Valor de Venda'], label='Gasolina', color = 'yellow',linewidth=3,marker='o')
ax.plot(preco_etanol_abril.index , preco_etanol_abril['Valor de Venda'], label='Etanol', color = 'green',linewidth=3,marker='o')
ax.plot(preco_aditivada_abril.index , preco_aditivada_abril['Valor de Venda'], label='Etanol', color = 'red',linewidth=3,marker='o')

# Adicionando legendas e título
ax.legend()
ax.set_xlabel('Data')
ax.set_ylabel('Preço médio de revenda')
ax.set_title('COMPORTAMENTO DE PREÇO- Abril/2023')
#ax.set_facecolor('black')
ax.grid(True)
# Mostrando o gráfico
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
preco_medio = relatorio[['Produto', 'Valor de Venda']].groupby('Produto').mean().round(2)
preco_medio
# Out:
#                     Valor de Venda
# Produto
# ETANOL                        4.15
# GASOLINA                      5.51
# GASOLINA ADITIVADA            5.69

# %%
preco_medio.plot.bar(color = 'black')
# Out:
# <Axes: xlabel='Produto'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Gasolina

# %%
carogasolina = gasolina[['Estado - Sigla', 'Valor de Venda']].groupby('Estado - Sigla').mean().sort_values(by = 'Valor de Venda', ascending = False).round(2)
carogasolina.iloc[:5]
# Out:
#                 Valor de Venda
# Estado - Sigla
# AM                        6.49
# RR                        6.09
# RO                        5.99
# AC                        5.93
# RN                        5.87

# %% [markdown]
# * Etanol

# %%
caroetanol = etanol[['Estado - Sigla', 'Valor de Venda']].groupby('Estado - Sigla').mean().sort_values(by = 'Valor de Venda', ascending = False).round(2)
caroetanol.iloc[:5]
# Out:
#                 Valor de Venda
# Estado - Sigla
# AP                        5.22
# RO                        4.91
# RS                        4.91
# RR                        4.91
# PA                        4.78

# %% [markdown]
# * Gasolina Aditivada

# %%
caroaditivada = gasolina_aditivada[['Estado - Sigla', 'Valor de Venda']].groupby('Estado - Sigla').mean().sort_values(by = 'Valor de Venda', ascending = False).round(2)
caroaditivada.iloc[:5]
# Out:
#                 Valor de Venda
# Estado - Sigla
# AM                        6.52
# RR                        6.16
# RO                        6.08
# CE                        5.99
# AC                        5.97

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Preço médio da gasolina por estado

# %%
carogasolina
# Out:
#                 Valor de Venda
# Estado - Sigla
# AM                        6.49
# RR                        6.09
# RO                        5.99
# AC                        5.93
# RN                        5.87
# CE                        5.86
# BA                        5.86
# AL                        5.78
# TO                        5.72
# PI                        5.64
# ES                        5.64
# PA                        5.62
# RJ                        5.60
# PR                        5.58
# SC                        5.55
# DF                        5.55
# GO                        5.49
# MA                        5.48
# MT                        5.47
# RS                        5.46
# PE                        5.41
# SE                        5.41
# MS                        5.39
# MG                        5.36
# SP                        5.34
# PB                        5.30
# AP                        5.17

# %% [markdown]
# * Preço médio do etanol por estado

# %%
caroetanol
# Out:
#                 Valor de Venda
# Estado - Sigla
# AP                        5.22
# RO                        4.91
# RS                        4.91
# RR                        4.91
# PA                        4.78
# CE                        4.66
# SC                        4.65
# MA                        4.62
# AM                        4.59
# RN                        4.58
# BA                        4.54
# TO                        4.53
# ES                        4.50
# RJ                        4.50
# PI                        4.49
# AC                        4.43
# AL                        4.38
# SE                        4.20
# PE                        4.18
# PR                        4.08
# DF                        4.04
# GO                        4.04
# MS                        4.01
# PB                        4.00
# MG                        3.92
# SP                        3.84
# MT                        3.64

# %% [markdown]
# * Preço médio da gasolina aditivada por estado

# %%
caroaditivada
# Out:
#                 Valor de Venda
# Estado - Sigla
# AM                        6.52
# RR                        6.16
# RO                        6.08
# CE                        5.99
# AC                        5.97
# BA                        5.97
# RN                        5.95
# AL                        5.93
# TO                        5.86
# PA                        5.85
# PI                        5.84
# ES                        5.81
# PR                        5.74
# RJ                        5.74
# SC                        5.67
# DF                        5.66
# RS                        5.65
# MT                        5.61
# GO                        5.60
# MA                        5.59
# SP                        5.59
# MS                        5.57
# PE                        5.57
# MG                        5.55
# SE                        5.48
# PB                        5.44
# AP                        5.43

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Municipio que possui o menor preço para gasolina

# %%
carogasolina_municipio = gasolina[['Municipio', 'Valor de Venda']].groupby('Municipio').mean().sort_values(by = 'Valor de Venda').round(2)
carogasolina_municipio.head(5)
# Out:
#            Valor de Venda
# Municipio
# TAUBATE              5.01
# DOURADOS             5.02
# LAJEDO               5.04
# JACAREI              5.05
# LEME                 5.06

# %% [markdown]
# * Municipio que possui o menor preço para o etanol

# %%
caroetanol_municipio = etanol[['Municipio', 'Valor de Venda']].groupby('Municipio').mean().sort_values(by = 'Valor de Venda').round(2)
caroetanol_municipio.head(5)
# Out:
#                        Valor de Venda
# Municipio
# LINS                             3.52
# VARZEA GRANDE                    3.56
# VOTUPORANGA                      3.58
# SAO JOSE DO RIO PRETO            3.58
# JOSE BONIFACIO                   3.62

# %% [markdown]
# * Municipio que possui o menor preço para gasolina aditivada

# %%
caroaditivada_municipio = gasolina_aditivada[['Municipio', 'Valor de Venda']].groupby('Municipio').mean().sort_values(by = 'Valor de Venda').round(2)
caroaditivada_municipio.head(5)
# Out:
#                      Valor de Venda
# Municipio
# LAJEDO                         5.12
# GARCA                          5.14
# ANAPOLIS                       5.20
# GARANHUNS                      5.21
# SAO JOSE DOS CAMPOS            5.21

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Municipio que possui o maior preço para gasolina

# %%
carogasolina_municipio.tail(1)
# Out:
#            Valor de Venda
# Municipio
# TEFE                 7.31

# %% [markdown]
# * Municipio que possui o maior preço para etanol

# %%
caroetanol_municipio.iloc[-1:]
# Out:
#            Valor de Venda
# Municipio
# BAGE                 5.71

# %% [markdown]
# * Municipio que possui o maior preço para gasolina aditivada

# %%
caroaditivada_municipio.iloc[-1:]
# Out:
#            Valor de Venda
# Municipio
# TEFE                 7.31

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
carogasolina_regiao = gasolina[['Regiao - Sigla', 'Valor de Venda']].groupby('Regiao - Sigla').mean().sort_values(by = 'Valor de Venda', ascending = False).round(2)
carogasolina_regiao
# Out:
#                 Valor de Venda
# Regiao - Sigla
# N                         5.86
# NE                        5.66
# S                         5.53
# CO                        5.48
# SE                        5.40

# %%
carogasolina_regiao.plot.line()
# Out:
# <Axes: xlabel='Regiao - Sigla'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
caroetanol_regiao = etanol[['Regiao - Sigla', 'Valor de Venda']].groupby('Regiao - Sigla').mean().sort_values(by = 'Valor de Venda').round(2)
caroetanol_regiao
# Out:
#                 Valor de Venda
# Regiao - Sigla
# CO                        3.97
# SE                        3.98
# S                         4.38
# NE                        4.44
# N                         4.67

# %%
caroetanol_regiao.plot.line()
# Out:
# <Axes: xlabel='Regiao - Sigla'>

# %% [markdown]
# ### Qual a região que possui o maior valor médio de gasolina aditivada?

# %%
caroaditivada_regiao = gasolina_aditivada[['Regiao - Sigla', 'Valor de Venda']].groupby('Regiao - Sigla').mean().sort_values(by = 'Valor de Venda', ascending = False).round(2)
caroaditivada_regiao
# Out:
#                 Valor de Venda
# Regiao - Sigla
# N                         6.04
# NE                        5.81
# S                         5.68
# SE                        5.62
# CO                        5.61

# %%
caroaditivada_regiao.plot.line()
# Out:
# <Axes: xlabel='Regiao - Sigla'>

# %% [markdown]
# # 9 correlaçao

# %%
a = gasolina[['Regiao - Sigla','Valor de Venda']]
a['Regiao - Sigla'] = a['Regiao - Sigla'].map({'N':5,
                             'NE': 4,
                            'S': 3,
                            'CO': 2,
                            'SE': 1},
                             na_action=None)
a.corr()
# Out:
# <ipython-input-111-d555df8c14d7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['Regiao - Sigla'] = a['Regiao - Sigla'].map({'N':5,
#                 Regiao - Sigla  Valor de Venda
# Regiao - Sigla        1.000000        0.375517
# Valor de Venda        0.375517        1.000000

# %%
a = etanol[['Regiao - Sigla','Valor de Venda']]
a['Regiao - Sigla'] = a['Regiao - Sigla'].map({'N':5,
                             'NE': 4,
                            'S': 3,
                            'SE': 2,
                            'CO': 1},
                             na_action=None)
a.corr()
# Out:
# <ipython-input-112-be29bdfdd957>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['Regiao - Sigla'] = a['Regiao - Sigla'].map({'N':5,
#                 Regiao - Sigla  Valor de Venda
# Regiao - Sigla        1.000000        0.499489
# Valor de Venda        0.499489        1.000000

# %%
a = gasolina_aditivada[['Regiao - Sigla','Valor de Venda']]
a['Regiao - Sigla'] = a['Regiao - Sigla'].map({'N':5,
                             'NE': 4,
                            'S': 3,
                            'SE': 2,
                            'CO': 1},
                             na_action=None)
a.corr()
# Out:
# <ipython-input-113-6fe9e123fc1a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['Regiao - Sigla'] = a['Regiao - Sigla'].map({'N':5,
#                 Regiao - Sigla  Valor de Venda
# Regiao - Sigla        1.000000        0.292162
# Valor de Venda        0.292162        1.000000

# %% [markdown]
# # 10 correlação bandeira

# %%
b = gasolina.loc[gasolina['Municipio'] == 'NOVA IGUACU']
b
# Out:
#       Regiao - Sigla Estado - Sigla    Municipio  \
# 4285              SE             RJ  NOVA IGUACU
# 4288              SE             RJ  NOVA IGUACU
# 4291              SE             RJ  NOVA IGUACU
# 4294              SE             RJ  NOVA IGUACU
# 4296              SE             RJ  NOVA IGUACU
# ...              ...            ...          ...
# 87783             SE             RJ  NOVA IGUACU
# 87786             SE             RJ  NOVA IGUACU
# 89591             SE             RJ  NOVA IGUACU
# 89620             SE             RJ  NOVA IGUACU
# 89642             SE             RJ  NOVA IGUACU
#
#                                                 Revenda      CNPJ da Revenda  \
# 4285         POSTO DE GASOLINA DO CAPITAO NA POSSE LTDA   03.219.097/0001-16
# 4288   POSTO DE GASOLINA E LANCHONETE JRH VITÓRIA LTDA.   07.926.437/0001-08
# 4291         MORAES E ELIAS AUTO POSTO DE SERVICOS LTDA   05.432.930/0001-38
# 4294       MEGA NOVA IGUACU POSTO DE ABASTECIMENTO LTDA   06.179.155/0001-13
# 4296               POSTO DE GASOLINA SIRIQUISAMBA LTDA.   07.106.399/0001-39
# ...                                                 ...                  ...
# 87783                          POSTO LIGHT HIGHWAY LTDA   03.475.408/0001-08
# 87786                  AUTO POSTO PORTAL DO TINGUÁ LTDA   02.710.975/0001-39
# 89591                        AUTO POSTO VIA IGUACU LTDA   11.078.304/0001-98
# 89620        POSTO DE COMBUSTÍVEIS MAIOR DA POSSE LTDA.   05.791.833/0001-31
# 89642                     POSTO DE GNV SERVAUTO II LTDA   10.371.066/0001-41
#
#                                              Nome da Rua Numero Rua  \
# 4285                                    RUA GENI SARAIVA         10
# 4288                               ESTRADA PLÍNIO CASADO       1630
# 4291                                       RUA DO RETIRO        S/N
# 4294                       AVENIDA ABILIO AUGUSTO TAVORA       3500
# 4296                 AVENIDA GOVERNADOR ROBERTO SILVEIRA       1500
# ...                                                  ...        ...
# 87783  RUA OSCAR SOARES (CONTINUACAO COMO EST DR PLIN...         36
# 87786                               RUA ALVARO GONÇALVES         30
# 89591              ESTRADA DEP. DARCILIO AYRES RAUNHETTI        560
# 89620               AVENIDA HENRIQUE DUQUE ESTRADA MEYER       1070
# 89642                    RODOVIA PRESIDENTE DUTRA BR 116       2560
#
#                                              Complemento           Bairro  \
# 4285                                                 NaN       PONTO CHIC
# 4288                                                 NaN        VILA NOVA
# 4291                                     LOTE 1/QUADRA B     MIGUEL COUTO
# 4294                                                 NaN  JARDIM ALVORADA
# 4296                                                 NaN          MOQUETA
# ...                                                  ...              ...
# 87783                                                NaN           CENTRO
# 87786                                                NaN     VILA DE CAVA
# 89591  LOTES 01,02,03 E 04       ANTIGA ESTRADA      ...          CAIOABA
# 89620                                                NaN            POSSE
# 89642                                                NaN           AUSTIN
#
#              Cep   Produto Data da Coleta  Valor de Venda  Valor de Compra  \
# 4285   26032-662  GASOLINA     04/04/2023            5.49              NaN
# 4288   26010-042  GASOLINA     04/04/2023            5.25              NaN
# 4291   26062-170  GASOLINA     04/04/2023            5.49              NaN
# 4294   26210-000  GASOLINA     04/04/2023            5.39              NaN
# 4296   26020-740  GASOLINA     04/04/2023            5.19              NaN
# ...          ...       ...            ...             ...              ...
# 87783  26220-099  GASOLINA     28/03/2023            5.39              NaN
# 87786  26210-000  GASOLINA     28/03/2023            5.80              NaN
# 89591  26210-000  GASOLINA     28/03/2023            5.29              NaN
# 89620  26030-380  GASOLINA     28/03/2023            5.19              NaN
# 89642  26031-000  GASOLINA     28/03/2023            5.29              NaN
#
#       Unidade de Medida Bandeira    Mes
# 4285         R$ / litro   RAIZEN  ABRIL
# 4288         R$ / litro   BRANCA  ABRIL
# 4291         R$ / litro   BRANCA  ABRIL
# 4294         R$ / litro   BRANCA  ABRIL
# 4296         R$ / litro   BRANCA  ABRIL
# ...                 ...      ...    ...
# 87783        R$ / litro   BRANCA  MARÇO
# 87786        R$ / litro   ALESAT  MARÇO
# 89591        R$ / litro   BRANCA  MARÇO
# 89620        R$ / litro   BRANCA  MARÇO
# 89642        R$ / litro   BRANCA  MARÇO
#
# [112 rows x 17 columns]

# %%
c= b[['Bandeira','Valor de Venda']].groupby('Bandeira').mean().sort_values(by='Valor de Venda')
c
# Out:
#                Valor de Venda
# Bandeira
# BRANCA               5.340606
# VIBRA ENERGIA        5.415000
# RAIZEN               5.440000
# IPIRANGA             5.465000
# ALESAT               5.753333

# %%
c.plot.line()
# Out:
# <Axes: xlabel='Bandeira'>

# %%
c.corr()
# Out:
#                 Valor de Venda
# Valor de Venda             1.0
